# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives**
# * Learn different catagories of Data Science Tools
# * List popular languages for Data Science
# * List commonly used libraries by Data Scientisth
# * Learn about Jupyter Notebooks and Jupyter Lab
# * Github & Rstudio

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 4. SQL

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. numpy
# 2. plotly
# 3. pandas
# 4. scikit-learn

# %%
# %%html
# <style>
# table {float:left}
# </style>
# Out:
# <style>
# table {float:left}
# </style>

# %% [markdown]
# | Data Science Tools |
# | :----------------|
# |Jupyter Notebook |
# | RStudio  |
# | VS Code |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %%
#This a simple arithmetic expression to mutiply then add integers

# %%
(3*4)+5
# Out:
# 17

# %%
#This will convert 200 minutes to hours by diving by 60

# %%
mins = 200 
hours = mins / 60 
print (hours)
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author ##
# Shikshya Bhattachan
